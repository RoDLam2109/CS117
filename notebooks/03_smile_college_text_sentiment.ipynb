# %% [markdown]
# # SMILE College Text Sentiment Analysis
# ## Module 3: Text-Based Risk Detection via Sentiment Analysis
#
# This notebook analyzes text data and sentiment from SMILE College dataset.
