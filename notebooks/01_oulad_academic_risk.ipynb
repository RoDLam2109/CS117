# %% [markdown]
# # OULAD Academic Risk Analysis
# ## Module 1: Academic Risk Detection
#
# This notebook analyzes academic risk using OULAD dataset.

# %%
import pandas as pd
import numpy as np
from src.preprocessing.preprocess_oulad import preprocess_oulad
from src.models.academic_model import AcademicRiskModel
